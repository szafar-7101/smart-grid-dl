# %%
import pandas as pd

df = pd.read_parquet('/Users/syedadnanzafar/smart-grid-dl/data/processed/panama_features.parquet')
print('Full dataset shape:', df.shape)
print('Date range:', df.index[0], 'to', df.index[-1])

# Take the last 30 days (720 hours) for testing
test_df = df.tail(720)
test_df.to_csv('panama_test_sample.csv', index=True)
print('Saved 720 rows to panama_test_sample.csv')
print('Columns:', list(test_df.columns))
# Out:
# Full dataset shape: (47880, 34)
# Date range: 0 to 47879
# Saved 720 rows to panama_test_sample.csv
# Columns: ['timestamp', 'load', 'temperature', 'humidity', 'TQL_toc', 'W2M_toc', 'T2M_san', 'QV2M_san', 'TQL_san', 'W2M_san', 'T2M_dav', 'QV2M_dav', 'TQL_dav', 'W2M_dav', 'Holiday_ID', 'holiday', 'school', 'hour', 'day_of_week', 'month', 'is_weekend', 'is_holiday', 'hour_sin', 'hour_cos', 'dayofweek_sin', 'dayofweek_cos', 'month_sin', 'month_cos', 'lag_1', 'lag_24', 'lag_168', 'rolling_mean_24', 'rolling_std_24', 'rolling_mean_168']
